# %% [markdown]
# # Explore knowledge base

# %%
import lancedb

db = lancedb.connect("../knowledge_base")
db
# Out:
# LanceDBConnection(uri='/Users/aigineer/Documents/demos/ai_engineering/rag_llmops_project_part1/rag/src/rag/explorations/../knowledge_base')

# %%
articles_table = db["articles"]
articles_table
# Out:
# LanceTable(name='articles', version=9, _conn=LanceDBConnection(uri='/Users/aigineer/Documents/demos/ai_engineering/rag_llmops_project_part1/rag/src/rag/explorations/../knowledge_base'))

# %%
articles_table.to_pandas()
# Out:
#   document_name                                           filepath  \
# 0     kanin.txt  /Users/aigineer/Documents/demos/ai_engineering...
# 1      hare.txt  /Users/aigineer/Documents/demos/ai_engineering...
# 2      fisk.txt  /Users/aigineer/Documents/demos/ai_engineering...
# 3       tax.txt  /Users/aigineer/Documents/demos/ai_engineering...
#
#                                              content  \
# 0  En kanin.\nKaniner\nsamlingsnamn för vissa art...
# 1  Harar och kaniner\nFälthare (Lepus europaeus)\...
# 2  Fiskar\nSystematik\nDomän Eukaryoter\nEukaryot...
# 3  Tax\nKorthårig tax (normalstor)\nRasgrupp\n(FC...
#
#                                            embedding
# 0  [0.034454346, -0.049591064, 0.021865845, -0.09...
# 1  [0.032104492, -0.023162842, 0.020812988, -0.05...
# 2  [0.031143188, 0.04147339, -0.032714844, -0.079...
# 3  [0.10070801, -0.04425049, 0.008529663, -0.1206...

# %%
articles_table.to_pandas()["embedding"].iloc[0].shape
# Out:
# (384,)
